# %% [markdown]
# # 🚀 Django Quickstart Guide ( From Setup to Mastery )

# %% [markdown]
# # Project's Overview

# %% [markdown]
# > Follow this Approach
#
# For Setup
# ```python
# project's settings.py -> project's urls.py -> app's views.py -> app's urls.py
# ```
#
#
# For Project
# ```python
# models.py -> admin.py -> views.py -> urls.py -> *.html (templates)
# ```

# %% [markdown]
# #### Directory Structure

# %% [markdown]
# ```python
# mysite/
# │
# ├── myapp/
# │   ├── models.py
# │   ├── admin.py
# │   ├── views.py
# │   ├── urls.py
# │   └─── templates/
# │          └── hello.html
# |
# ├── bookmarkapp/
# │   ├── models.py
# │   ├── admin.py
# │   ├── views.py
# │   ├── urls.py
# │   └─── templates/
# │         └── links.html
# |
# ├── media/
# │   └── uploads/
# |
# ├── static/
# │   └── css/
# │     └── styles.css
# |
# ├── templates/
# │      └── base.html
# │
# ├── myproject/
# │   ├── settings.py   # 01 - At first open the settings and add all configs
# │   └── urls.py
# |
# └── manage.py
# ```

# %% [markdown]
# # Setup

# %% [markdown]
# ## 🧰 Step 1: Environment Setup

# %% [markdown]
# ### Install Python (if not already)

# %% [markdown]
# #### windows

# %% [markdown]
# - Go to the official site: [https://www.python.org/downloads](https://www.python.org/downloads)
# - Download the latest stable version (e.g., Python 3.12.x)
# - **Windows Tip**: During installation, check ✅ “Add Python to PATH”

# %% [markdown]
# #### linux

# %% [raw]
# sudo apt install python3 python3-pip

# %% [markdown]
# ### Create Virtual Envirionment

# %% [raw]
# python -m venv myenv

# %% [markdown]
# ### Activate Environment

# %% [markdown]
# #### windows

# %% [raw]
# .\venv\Scripts\activate

# %% [markdown]
# #### linux

# %% [raw]
# sudo apt install python3 python3-pip

# %% [markdown]
# ### Install Django ( inside venv )

# %% [raw]
# pip install django

# %% [markdown]
# ### Verify installation:

# %% [markdown]
# Open your terminal or command prompt and run:

# %% [raw]
# django-admin --version

# %% [raw]
# python --version

# %% [markdown]
# You should see something like:
#
# Python 3.12.2

# %% [markdown]
# ### Tips

# %% [markdown]
# - Use 'pip list' to list all the installed libraries
# - Use `pip freeze > requirements.txt` to save dependencies
# - Use `deactivate` to exit virtual environment

# %% [markdown]
# # Project : `mysite`

# %% [markdown]
# ## 🏗️ Step 2: Create Your First Django Project

# %% [markdown]
# ### Start a new project:

# %% [raw]
# django-admin startproject mysite
# cd mysite

# %% [markdown]
# ### Run development server:

# %% [raw]
# python manage.py runserver

# %% [markdown]
# ### Launch Browser:

# %% [markdown]
# Visit http://127.0.0.1:8000/ to see the default Django welcome page

# %% [markdown]
# # App : `myapp`

# %% [markdown]
# ## 🧱 Step 3: Create an App

# %% [markdown]
# ### Create an app `myapp`

# %% [raw]
# python manage.py startapp myapp

# %% [markdown]
# ### Register the app in `mysite/settings.py`:

# %% [markdown]
# ```python
# # Application definition
# INSTALLED_APPS = [
#     ...
#     'myapp',
# ]
#
# ```

# %% [markdown]
# ### Register atemplates directory:

# %% [raw]
#  TEMPLATES = [
#     {
# 		 'DIRS': [BASE_DIR / 'templates'],
# 	}
# ]

# %% [markdown]
# ## 🌐 Step 4: Create Views and URLs

# %% [markdown]
# ### In `myapp/views.py`:

# %% [markdown]
# ```python
# from django.shortcuts import render
#
# # Create your views here.
#
# def my_app_view(request):
#
#      context = {
#         'heading' : 'Hello World'
#         }
#     return render(request, 'hello.html', context)
#
# ```

# %% [markdown]
# ### In `myapp/urls.py`:

# %% [markdown]
# ```python
# from django.urls import path
# from . import views
#
# urlpatterns = [
#     path('', views.my_app_view, name='my_app_view'),
# ]
#
# ```

# %% [markdown]
# ### In `mysite/urls.py`:

# %% [markdown]
# ```python
# from django.contrib import admin
# from django.urls import path, include
#
# urlpatterns = [
#     path('admin/', admin.site.urls),
#     path('', include('myapp.urls')),
# ]
# ```

# %% [markdown]
# ## 🧱 Step 4: Create a Directory `mysite/templates`

# %% [markdown]
# ### In `mysite/templates/base.html`:

# %% [markdown]
# ```html
# {% load static %}
#
# <html>
#     <head>
#         <meta name="viewport" content="width=device-width, initial-scale=1">
#         <title>Master Site</title>
#     </head>
#     <h1>Master Page</h1>
#     {% block content %} <h2> This is sample page</h2> {% endblock %}
#
# </html>
# ```

# %% [markdown]
# ### In `myapp/templates/hello.html`:

# %% [markdown]
# ```html
# {% extends 'base.html' %}
#
#     {% block content %}
#     <h1>{{ heading_one }}</h1>
#     {% endblock %}
# ```

# %% [markdown]
# ### Run the Server

# %% [raw]
# python manage.py runserver

# %% [markdown]
# # App : `bookmarkapp`

# %% [markdown]
# ## 🧱 Step 5: Create 2nd App (`bookmarkapp`)

# %% [markdown]
# ### Launch Browser:

# %% [raw]
# python manage.py startapp bookmarkapp

# %% [markdown]
# ### Register the app in `mysite/settings.py`:

# %% [markdown]
# ```python
# # Application definition
# INSTALLED_APPS = [
#     ...
#     'myapp',
#     'bookmarkapp',
# ]
#
# ```

# %% [markdown]
# ## 📄 Step 6: Define Models (Database Structure)

# %% [markdown]
# ### In `mysite/settings.py` (`db.sqlite3`)

# %% [markdown]
# ```python
# # Django's Local Database
#
# # https://docs.djangoproject.com/en/5.1/ref/settings/#databases
# DATABASES = {
# 			#'default': {
# 			#'ENGINE': 'django.db.backends.sqlite3',
# 			'NAME': BASE_DIR / 'db.sqlite3',
# 			}
# 		}
# ```

# %% [markdown]
# ### In `bookmarkapp/models.py`:

# %% [markdown]
# ```python
# from django.db import models
#
# # Create your models here.
#
# class BookmarkModel(models.Model):
#
#     title  = models.CharField(max_length=120)
#     link = models.CharField(max_length=60)
#     created_at = models.DateTimeField(auto_now_add=True)
#
#   ## Add below entries
#     STATUS_OPTION = [
#          ("active","ACTIVE"),
#         ("inactive","INACTIVE")
# 	    ]
#
#     status = models.CharField(max_length=120, choices=GENDER_OPTIONS,default="inactive")
#
# ## Already aded
# def __str__(self):
# 	return f"{self.title} - {self.link}"
#
# ```

# %% [markdown]
# ### Register model in `bookmarkapp/admin`.py:

# %% [markdown]
# ```python
# from django.contrib import admin
#
# from .models import BookmarkModel
#
# # Register your models here.
#
# class BookmarkModelAdmin(admin.ModelAdmin):
#     list_display = ("title", "link", "status")
#
# admin.site.register(BookmarkModel, BookmarkModelAdmin)
# ```

# %% [markdown]
# ### Apply migrations:

# %% [raw]
# python manage.py makemigrations
# python manage.py migrate

# %% [markdown]
# ## 🧑‍💻 Step 7: Create Admin Interface

# %% [markdown]
# ### Create superuser:

# %% [raw]
# python .\manage.py createsuperuser

# %% [markdown]
# ```python
# └─$ PS>python .\manage.py createsuperuser
# Username (leave blank to use 'samst'): stephan
# Email address: samstephan069@gmail.com
# Password: 1122
# Password (again): 1122
# This password is too short. It must contain at least 8 characters.
# This password is entirely numeric.
# Bypass password validation and create user anyway? [y/N]: y
# Superuser created successfully.
# ```

# %% [markdown]
# ### Login to `localhost/admin`

# %% [markdown]
# Visit http://127.0.0.1:8000/admin and log in.

# %% [markdown]
# ### Add Few Entries in the `localhost/admin`

# %% [markdown]
# ## 🧑‍💻 Step 8: Define Views and Create a URLs

# %% [markdown]
# ### In the `bookmarkapp/views.py`

# %% [markdown]
# ```python
# from django.shortcuts import render
# from .models import MyHomeappModel
#
# linksinfo = MyHomeappModel.objects.all()
#
# # Create your views here.
#
# def my_home_view(request):
#
#     context = {
#         "linksinfo": linksinfo
#     }
#     return render(request, 'home.html', context)
# ```

# %% [markdown]
# ### In the `bookmarkapp/urls.py`

# %% [markdown]
# ```python
# from django.urls import path
#
# from . import views
#
# urlpatterns = [
#     path('' , views.my_home_view, name='my_home_view')
#
# ]
# ```

# %% [markdown]
# ### In the `bookmarkapp/templates/links.html`

# %% [markdown]
# ```python
# {% load static %}
#
# <ol>
#
#    {% for link in linksinfo %}
#
#    <li><a href="{{ link.link }}" >{{ link.title }}</a>  - ( {{ link.link }} ) </li>
#
#    {% endfor %}
#
# </ol>
# ```

# %% [markdown]
# # App : `imageapp`

# %% [markdown]
# ## 🧑‍💻 Step 9 : Update `mysite/settings.py`

# %% [markdown]
# ### Add `import os` in the `mysite/settings.py`

# %%
import os

# %% [markdown]
# ### Add `MEDIA_ROOT` path in `mysite/settings.py`

# %% [markdown]
# ```python
# MEDIA_ROOT = os.path.join(BASE_DIR,'media')
# MEDIA_URL = '/media/'
# ```

# %% [markdown]
# ### Create a media directory at the root

# %% [markdown]
# ```python
# root/
# │
# ├── imageapp/
# │   ├── views.py
# │   ├─── urls.py
# │   └─── static/
# │   	├── index.html
# │   	├── style.css
# │   	└── script.js
# |
# ├── media/
# │   └── uploads
# │
# ├── myproject/
# │   ├── settings.py
# │   └── urls.py
# |
# │
# └── manage.py
# ```

# %% [markdown]
# ### Add `upload_to` in the `imageapp/models.py`

# %% [markdown]
# ```python
# from django.db import models
#
# # Create your models here.
#
# class ImageModel(models.Model):
#
#     image = models.ImageField(upload_to='uploads/')  ## add this entry
#     title  = models.CharField(max_length=120)
#
# def __str__(self):
# 	return f"{self.name} - {self.profession}"
# ```

# %% [markdown]
# ### In the `imageapp/admins.py`

# %% [markdown]
# ```python
# from django.contrib import admin
# from .models import ImageModel
#
# class ImageAppModelAdmin(admin.ModelAdmin):
#     list_display = ("image", "title")
#
# admin.site.register(ImageModel, ImageAppModelAdmin)
# ```

# %% [markdown]
# ### Apply migrations:

# %% [raw]
# python manage.py makemigrations
# python manage.py migrate

# %% [markdown]
# ### In the `imageapp/views.py`

# %% [markdown]
# ```python
# from django.shortcuts import render
# from django.shortcuts import render, get_object_or_404
# from myapp.models import MyAppModel
#
# # Create your views here.
#
# def the_profile_detail_view(request, id):
#
#     profiledata = get_object_or_404(MyAppModel, id=id)
#
#     context = {
#
#         'tilte' : "Person Profile Details",
#
#         'profile' : profiledata
#
#     }
#
#     return render(request, 'profile_details.html', {'profile': profiledata})
# ```

# %% [markdown]
# ### In the `imageapp/urls.py`

# %% [markdown]
# ```python
# from django.urls import path
#
# from django.conf import settings
#
# from django.conf.urls.static import static
#
# from . import views
#
#
#
# urlpatterns = [
#
#     path('profile/detail/<int:id>/', view=views.the_profile_detail_view, name='the_profile_detail_view')
#
# ] + static(settings.MEDIA_URL, document_root=settings.MEDIA_ROOT )
# ```

# %% [markdown]
# ### In the `imageapp/static/autohideimage.html`

# %% [markdown]
# ```html
# {% load static %}
#
# <!DOCTYPE html>
#
# <html lang="en">
#
# <head>
#
#   <meta charset="UTF-8" />
#
#   <meta name="viewport" content="width=device-width, initial-scale=1.0" />
#
#   <title>My Resume</title>
#
#   <link rel="stylesheet" href="{% static 'style.css' %}" />
#
# </head>
#
# <body>
#
#   <div class="resume-container">
#
#     <button onclick="showImage()" class="show-btn">Show Profile Image</button>
#
#     <img src="{{ profile.image.url }}" alt="Profile Image" class="profile-img" id="profileImage" style="display: none;" />
#
#     <h1 class="name">{{ profile.name }}</h1>
#
#     <p><strong>Gender:</strong> {{ profile.gender }}</p>
#
#     <p><strong>Hobby:</strong> {{ profile.hobby }}</p>
#
#   </div>
#
#
#
#   <script>
#
#     function showImage() {
#
#       const img = document.getElementById("profileImage");
#
#       img.style.display = "block";
#
#     }
#
#   </script>
#
# </bodyb>
#
# </html>
#
# ```

# %% [markdown]
# #### What This `autohideimage.html` Does!

# %% [markdown]
# - The profile image is hidden by default (`display: none`).
# - When the button is clicked, the image becomes visible (`display: block`).

# %% [markdown]
# ### In the `imageapp/static/style.css`

# %% [markdown]
# ```css
# body {
#   background-color: #f0f4f8;
#   font-family: 'Segoe UI', sans-serif;
#   display: flex;
#   justify-content: center;
#   align-items: center;
#   height: 100vh;
#   margin: 0;
# }
#
# .resume-container {
#   background-color: #fff;
#   padding: 30px;
#   border-radius: 12px;
#   box-shadow: 0 6px 16px rgba(0, 0, 0, 0.1);
#   text-align: center;
#   width: 300px;
# }
#
# .profile-img {
#   width: 120px;
#   height: 120px;
#   border-radius: 50%;
#   object-fit: cover;
#   margin: 20px auto;
# }
#
# .name {
#   font-size: 24px;
#   margin-bottom: 10px;
#   color: #333;
# }
#
# p {
#   font-size: 16px;
#   color: #555;
#   margin: 8px 0;
# }
#
# .show-btn {
#   padding: 10px 20px;
#   font-size: 16px;
#   background-color: #0077cc;
#   color: white;
#   border: none;
#   border-radius: 8px;
#   cursor: pointer;
#   margin-bottom: 10px;
# }
#
# .show-btn:hover {
#   background-color: #005fa3;
# }
#
# ```

# %% [markdown]
# ### In the `imageapp/templates/member.html`

# %% [markdown]
# ```html
# <a href="profile/detail/1"> Person 1</a>
# <!--    [My Resume](http://127.0.0.1:8000/profile/detail/1/)    -->
# ```

# %% [markdown]
# ## 🚀 Step 9: Run the Server

# %% [raw]
# python manage.py runserver

# %% [markdown]
# ## 🚀 Step 10: Deployment (Optional for Mastery)

# %% [markdown]
# Use Gunicorn + Nginx or deploy to Heroku or PythonAnywhere.
#
# Collect static files:

# %% [raw]
# python manage.py collectstatic

# %% [markdown]
# ## 🧠 Mastery Path: What to Learn Next

# %% [markdown]
# | Skill Area            | What to Explore Next                          |
# |-----------------------|-----------------------------------------------|
# | Models                | Relationships (ForeignKey, ManyToMany)       |
# | Views                 | Class-based views (CBVs)                      |
# | Templates             | Template inheritance, filters                 |
# | Forms                 | Custom validation, crispy-forms               |
# | Authentication        | Login, logout, user registration              |
# | REST APIs             | Django REST Framework (DRF)                   |
# | Deployment            | Docker, CI/CD, cloud platforms                |
# | Performance           | Caching, query optimization                   |
